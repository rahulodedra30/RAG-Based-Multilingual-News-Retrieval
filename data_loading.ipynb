# %%
import pandas as pd
from datasets import load_dataset
from langdetect import detect

# Initialize an empty list to store DataFrames for each language
dataframes = []

# Define the list of language configurations
languages = ['de', 'es', 'fr', 'ru', 'tu']

# Load the dataset for each language configuration
for lang in languages:
    print(f"Loading MLSUM dataset for language: {lang}")
    dataset = load_dataset('mlsum', lang, trust_remote_code=True)
    
    # Convert to pandas DataFrame for easier manipulation
    df = pd.DataFrame(dataset['train'])
    
    # Add a column for language
    df['language'] = lang
    
    # Append the DataFrame to the list
    dataframes.append(df)

# Concatenate all DataFrames into one
all_data = pd.concat(dataframes, ignore_index=True)

# Display the first few rows of the combined dataset
print("Combined Data:")
print(all_data.head())

# Filter to keep relevant columns
filtered_df = all_data[['text', 'summary', 'topic', 'url', 'title', 'date', 'language']]

# Display the filtered DataFrame
print("Filtered Data with Language Detection:")
print(filtered_df.head())

# Optionally, save the filtered DataFrame to a CSV file for further use
# filtered_df.to_csv('mlsum_filtered_articles.csv', index=False)
# print("Filtered Data Saved to CSV.")
# Out:
# Loading MLSUM dataset for language: de
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~/Downloads/NLP/Project/.venv/lib/python3.10/site-packages/aiohttp/connector.py:1098, in TCPConnector._wrap_create_connection(self, addr_infos, req, timeout, client_error, *args, **kwargs)
#    1091         sock = await aiohappyeyeballs.start_connection(
#    1092             addr_infos=addr_infos,
#    1093             local_addr_infos=self._local_addr_infos,
#    (...)
#    1096             loop=self._loop,
#    1097         )
# -> 1098         return await self._loop.create_connection(*args, **kwargs, sock=sock)
#    1099 except cert_errors as exc:
#
# ...

# %%
import os
from datasets import load_dataset

# Temporarily disable SSL verification 
# os.environ['CURL_CA_BUNDLE'] = ""
dataset = load_dataset("mlsum", "es")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~/Downloads/NLP/Project/.venv/lib/python3.10/site-packages/aiohttp/connector.py:1098, in TCPConnector._wrap_create_connection(self, addr_infos, req, timeout, client_error, *args, **kwargs)
#    1091         sock = await aiohappyeyeballs.start_connection(
#    1092             addr_infos=addr_infos,
#    1093             local_addr_infos=self._local_addr_infos,
#    (...)
#    1096             loop=self._loop,
#    1097         )
# -> 1098         return await self._loop.create_connection(*args, **kwargs, sock=sock)
#    1099 except cert_errors as exc:
#
# ...

# %%
from datasets import load_dataset

dataset = load_dataset("wiki_lingua",trust_remote_code=True)
# Out:
# Generating train split: 100%|██████████| 57945/57945 [00:00<00:00, 117141.99 examples/s]
